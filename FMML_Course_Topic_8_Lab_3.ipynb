# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyothi191022/FMML-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 05:36:39--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   275MB/s    in 0.3s
#
# 2023-05-05 05:36:42 (275 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 30179  1711.08502v1  Despite the growing discriminative capabilitie...    cs
# 11444  1602.03571v3  This paper presents a new approach, called per...    cs
# 11099   1407.0726v2  This paper describes a fast algorithm for reco...  stat
# 32065   1109.2047v1  There has been increased interest in devising ...    cs
# 24274   1211.3901v1  We present a method for recognition of isolate...    cs
# ...             ...                                                ...   ...
# 9748   1612.08543v1  Big data trend has enforced the data-centric s...  stat
# 25062  1504.04871v1  Most of the approaches for discovering visual ...    cs
# 4981   1707.01166v3  Unsupervised rank aggregation on score-based p...    cs
# 38438  1801.00841v1  We investigate training end-to-end speech reco...    cs
# 20325  1509.03585v1  Dung's abstract argumentation framework consis...    cs
#
#                                                    title  year  \
# 30179  Train, Diagnose and Fix: Interpretable Approac...  2017
# 11444  High Dimensional Inference with Random Maximum...  2016
# 11099  Fast Algorithm for Low-rank matrix recovery in...  2014
# 32065  Learning From Labeled And Unlabeled Data: An E...  2011
# 24274  Visual Recognition of Isolated Swedish Sign La...  2012
# ...                                                  ...   ...
# 9748   Distributed Real-Time Sentiment Analysis for B...  2016
# 25062  DEEP-CARVING: Discovering Visual Attributes by...  2015
# 4981   Unsupervised Submodular Rank Aggregation on Sc...  2017
# 38438  Exploring Architectures, Data and Units For St...  2018
# 20325  Some Supplementaries to The Counting Semantics...  2015
#
#                                                 keywords
# 30179  [discriminative, capabilities, recognition, sy...
# 11444  [dimensional, statistical, inference, perturba...
# 11099  [describes, algorithm, recovering, measurement...
# 32065  [increased, techniques, unlabeled, supervised,...
# 24274  [recognition, complement, primarily, disorders...
# ...                                                  ...
# 9748   [continuous, analytics, happening, negligible,...
# 25062  [approaches, discovering, attributes, signific...
# 4981   [unsupervised, aggregation, permutations, appl...
# 38438  [investigate, recognition, recurrent, transduc...
# 20325  [argumentation, framework, interacting, argume...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 30179    [discriminative, capabilities, recognition, sy...
# 11444    [dimensional, statistical, inference, perturba...
# 11099    [describes, algorithm, recovering, measurement...
# 32065    [increased, techniques, unlabeled, supervised,...
# 24274    [recognition, complement, primarily, disorders...
#                                ...
# 38239    [complexity, approximating, structure, bijecti...
# 37925    [framework, important, directions, exploiting,...
# 24490    [potential, capability, representations, vecto...
# 21627    [naturally, sparseness, functions, conditional...
# 20610    [investigate, heuristics, heuristic, regressio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8822 words.
# Out of those 4551 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9bf1956f-f38f-46c3-b8b2-57240e91b625" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9bf1956f-f38f-46c3-b8b2-57240e91b625")) {                    Plotly.newPlot(                        "9bf1956f-f38f-46c3-b8b2-57240e91b625",                        [{"x":["discriminative","introduces","recognition","convolutional","interpretable","benchmark","generalize","variables","technique","representations","characteristic","systematic","performance","representation","diagnosis","invariance","parameters","capabilities","rotational","interpretation","implicitly","resulting","discovered","effective","refinement","normalization","generating","statistical","unfortunately","potential","inference","exponentially","posteriori","statistics","framework","computational","dimension","concentration","sequentially","optimization","randomness","operations","expectation","dimensional","approximation","perturbing","predictors","perturbations","prohibitive","prediction","furthermore","deviation","efficient","distribution","demonstrate","expanding","describes","approximate","measurements","recovering","iterative","generates","thresholding","regularization","algorithm","consisting","contaminated","likelihood","formulation","implement","published","associated","empirical","different","unlabeled","particularly","potentially","supervised","relevance","investigate","techniques","independence","increased","bivariate","knowledge","distributions","selection","performed","questions","correcting","regardless","vocabulary","independent","development","primarily","distinguish","complement","dependent","challenging","resolution","advantages","discriminant","experiments","occlusion","combinations","differences","conversation","backgrounds","precision","stimulate","information","robustness","descriptive","disorders","classification","vertically","estimated","observable","projection","theoretical","converges","procedure","discussed","particular","generalization","nonlinear","dedicated","residuals","illustrations","exhibited","simulated","manifolds","principal","classical","properties","component","presented","candidates","established","implementation","structure","associative","approximating","aggregation","assumption","coefficients","regression","monotonic","benchmarks","orthogonal","convergence","experiment","algorithms","constraints","arbitrary","generalized","procrustes","satisfies","optimally","preparation","detection","possibility","extraction","prospects","addresses","evaluation","intensity","underlying","improving","eliminating","enhancement","foreground","encouraging","automated","signature","processing","identifies","contribution","isolating","biometric","segmentation","structural","represent","replacing","discovering","important","containing","represented","principle","repetitive","appropriate","substructures","hierarchical","identical","discovery","closeness","discovers","computationally","corresponding","compressing"],"y":[89,86,365,366,25,195,51,128,269,224,29,32,899,367,56,25,234,57,6,58,28,154,19,239,31,22,109,156,41,176,199,21,10,54,558,292,60,12,18,319,8,62,31,178,114,2,16,19,3,234,178,12,391,221,571,11,77,127,48,15,89,59,12,80,799,40,3,61,97,80,38,104,154,736,34,79,40,202,42,156,415,31,44,2,357,112,155,140,54,6,21,29,131,138,24,26,17,86,271,125,63,11,605,33,39,41,14,4,100,2,737,96,11,2,466,4,63,17,43,156,25,134,65,261,96,54,15,4,0,2,60,19,37,106,196,114,200,28,53,134,314,5,14,21,62,36,106,15,78,20,110,76,604,150,79,56,0,14,21,7,343,33,150,6,56,259,28,126,111,8,27,22,21,86,11,307,31,71,4,12,200,72,127,10,28,347,59,86,48,4,91,5,101,19,59,4,9,73,121,6],"type":"bar"},{"x":["discriminative","introduces","recognition","convolutional","interpretable","benchmark","gene ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4551,), (4551, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7925

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.8857142857142857);'>Semantically</span> <span style=''>Guided</span> <span style=''>Video</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.6877637130801687);'>Segmentation</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>tackles</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>video</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.6877637130801687);'>segmentation</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.6521739130434783);'>segmenting</span> <span style=''>an</span> <span style=''>object</span> <span style=''>in</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>given</span> <span style=''>its</span> <span style=''>mask</span> <span style=''>in</span> <span style=''>the</span> <span style=''>first</span> <span style=''>frame</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.32019704433497537);'>challenges</span> <span style=''>in</span> <span style=''>this</span> <span style=''>scenario</span> <span style=''>is</span> <span style=''>the</span> <span style=''>change</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.927710843373494);'>appearance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>objects</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>Their</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>semantics</span> <span style=''>on</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>do</span> <span style=''>not</span> <span style=''>vary</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.6111111111111112);'>investigates</span> <span style=''>how</span> <span style=''>to</span> <span style=''>take</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.5625);'>invariance</span> <span style=''>via</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduction</span> <span style=''>of</span> <span style=''>a</span> <span style=''>semantic</span> <span style=''>prior</span> <span style=''>that</span> <span style=''>guides</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.927710843373494);'>appearance</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3082706766917293);'>Specifically</span> <span style=''>given</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6877637130801687);'>segmentation</span> <span style=''>mask</span> <span style=''>of</span> <span style=''>the</span> <span style=''>first</span> <span style=''>frame</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>we</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>semantics</span> <span style=''>of</span> <span style=''>the</span> <span style=''>object</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.368421052631579);'>propagate</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3864077669902911);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>throughout</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>to</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variables</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>Existing</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>the</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>superposition</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>which</span> <span style=''>encodes</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginalization</span> <span style=''>over</span> <span style=''>the</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>fast</span> <span style=''>proper</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>with</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>manifestly</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>We</span> <span style=''>support</span> <span style=''>their</span> <span style=''>efficacy</span> <span style=''>via</span> <span style=''>a</span> <span style=''>rigorous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>match</span> <span style=''>the</span> <span style=''>best</span> <span style=''>possible</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>while</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.6);'>Bipartite</span> <span style=''>ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>survival</span> <span style=''>analysis</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style=''>built</span> <span style='background-color:rgba(255, 0, 0, 0.6190476190476191);'>univariate</span> <span style='background-color:rgba(255, 0, 0, 0.37254901960784315);'>predictors</span> <span style=''>is</span> <span style=''>explored</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style='background-color:rgba(255, 0, 0, 0.3277310924369748);'>regularization</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>noisy</span> <span style=''>sparse</span> <span style=''>datasets</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>Bipartite</span> <span style=''>ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>Smooth</span> <span style=''>Rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementing</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>on</span> <span style=''>two</span> <span style=''>types</span> <span style=''>of</span> <span style=''>problems</span> <span style=''>First</span> <span style=''>Smooth</span> <span style=''>Rank</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>two</span> <span style=''>class</span> <span style=''>problems</span> <span style=''>from</span> <span style=''>bio</span> <span style=''>medical</span> <span style=''>field</span> <span style=''>where</span> <span style=''>ranking</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preferable</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>against</span> <span style=''>SVMs</span> <span style=''>with</span> <span style=''>radial</span> <span style=''>and</span> <span style=''>linear</span> <span style=''>kernels</span> <span style=''>Smooth</span> <span style=''>Rank</span> <span style=''>had</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>8</span> <span style=''>out</span> <span style=''>of</span> <span style=''>12</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>benchmark</span> <span style='background-color:rgba(0, 255, 0, 0.38053097345132736);'>benchmarks</span> <span style=''>The</span> <span style=''>second</span> <span style=''>area</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>is</span> <span style=''>survival</span> <span style=''>analysis</span> <span style=''>which</span> <span style=''>is</span> <span style=''>reduced</span> <span style=''>here</span> <span style=''>to</span> <span style='background-color:rgba(255, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Kernel</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <span style=''>over</span> <span style=''>Graphs</span> <br/><br/><span style=''>The</span> <span style=''>study</span> <span style=''>of</span> <span style=''>networks</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>witnessed</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explosive</span> <span style=''>growth</span> <span style=''>over</span> <span style=''>the</span> <span style=''>past</span> <span style=''>decades</span> <span style=''>with</span> <span style=''>several</span> <span style=''>ground</span> <span style=''>breaking</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prevalent</span> <span style=''>in</span> <span style=''>several</span> <span style=''>fields</span> <span style=''>of</span> <span style=''>study</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>that</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>a</span> <span style=''>function</span> <span style=''>defined</span> <span style=''>over</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>of</span> <span style=''>a</span> <span style=''>network</span> <span style=''>This</span> <span style=''>work</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>versatile</span> <span style=''>kernel</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>tackling</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>problem</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>subsumes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>put</span> <span style=''>forth</span> <span style=''>recently</span> <span style=''>by</span> <span style=''>the</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>on</span> <span style=''>graphs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style=''>Both</span> <span style=''>the</span> <span style=''>static</span> <span style=''>and</span> <span style=''>the</span> <span style=''>dynamic</span> <span style=''>settings</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>along</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressing</span> <span style=''>real</span> <span style=''>world</span> <span style=''>problems</span> <span style=''>The</span> <span style=''>herein</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discussion</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12781954887218044)
# 	processing (0.10991765127103473)
# 	segmentation (0.07160759040458288)
# 	architecture (0.08843537414965986)
# 	representation (0.1313999283924096)
# 	different (0.26351593268886503)
# 	information (0.2638739706408879)
# 	detection (0.12280701754385964)
# 	convolutional (0.1310418904403867)
# 	recognition (0.13068385248836376)
#
# Some Statistics words are:
# 	estimation (0.16890881913303438)
# 	theoretical (0.14997508719481814)
# 	variables (0.14050822122571002)
# 	stochastic (0.13702042850024912)
# 	algorithm (0.38365719980069757)
# 	statistical (0.1554559043348281)
# 	distribution (0.1833582461385152)
# 	inference (0.19083208769307425)
# 	dimensional (0.19133034379671152)
# 	regression (0.17239661185849528)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="831d8950-6827-4d66-961e-ba90a3d23c1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("831d8950-6827-4d66-961e-ba90a3d23c1d")) {                    Plotly.newPlot(                        "831d8950-6827-4d66-961e-ba90a3d23c1d",                        [{"x":["discriminative","introduces","recognition","convolutional","interpretable","benchmark","generalize","variables","technique","representations","characteristic","systematic","performance","representation","diagnosis","invariance","parameters","capabilities","rotational","interpretation","implicitly","resulting","discovered","effective","refinement","normalization","generating","statistical","unfortunately","potential","inference","exponentially","posteriori","statistics","framework","computational","dimension","concentration","sequentially","optimization","randomness","operations","expectation","dimensional","approximation","perturbing","predictors","perturbations","prohibitive","prediction","furthermore","deviation","efficient","distribution","demonstrate","expanding","describes","approximate","measurements","recovering","iterative","generates","thresholding","regularization","algorithm","consisting","contaminated","likelihood","formulation","implement","published","associated","empirical","different","unlabeled","particularly","potentially","supervised","relevance","investigate","techniques","independence","increased","bivariate","knowledge","distributions","selection","performed","questions","correcting","regardless","vocabulary","independent","development","primarily","distinguish","complement","dependent","challenging","resolution","advantages","discriminant","experiments","occlusion","combinations","differences","conversation","backgrounds","precision","stimulate","information","robustness","descriptive","disorders","classification","vertically","estimated","observable","projection","theoretical","converges","procedure","discussed","particular","generalization","nonlinear","dedicated","residuals","illustrations","exhibited","simulated","manifolds","principal","classical","properties","component","presented","candidates","established","implementation","structure","associative","approximating","aggregation","assumption","coefficients","regression","monotonic","benchmarks","orthogonal","convergence","experiment","algorithms","constraints","arbitrary","generalized","procrustes","satisfies","optimally","preparation","detection","possibility","extraction","prospects","addresses","evaluation","intensity","underlying","improving","eliminating","enhancement","foreground","encouraging","automated","signature","processing","identifies","contribution","isolating","biometric","segmentation","structural","represent","replacing","discovering","important","containing","represented","principle","repetitive","appropriate","substructures","hierarchical","identical","discovery","closeness","discovers","computationally","corresponding","compressing","description","previously","instances","background","compressed","databases","essential","regularities","substructure","interesting","introduce","approaches","agreement","traditionally","constraint","degradation","motivation","significant","computation","significantly","assignments","utilitarian","distributed","integrate","fundamental","satisfaction","extensions","difference","limitations","limitation","conditions","scenarios","representing","improvement","including","application","microsoft","initialized","education","characters","practical","continuing","requirements","metaheuristic","communications","competitive","nieuwenhuis","correctness","transition","implemented","enhancements","describing","understanding","performances","diagnostic","indicative", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	illustrations
# 	procrustes
# 	refitting
# 	appreciated
# 	macroeconomic
# 	mortality
# 	breaching
# 	telescope
# 	representatives
# 	penalizes
# 	smoothers
# 	semiparametric
# 	changepoints
# 	changepoint
# 	revolutionize
# 	mitigates
# 	staleness
# 	beginnings
# 	periodicity
# 	statistician
# Some words which never appear in Statistics papers:
# 	rotational
# 	descriptive
# 	isolating
# 	repetitive
# 	utilitarian
# 	nieuwenhuis
# 	enhancements
# 	infographic
# 	infographics
# 	micromanagement
# 	centralised
# 	coordination
# 	starcraft
# 	pixelwise
# 	buildings
# 	negotiation
# 	possibilistic
# 	assistant
# 	withdrawn
# 	characterised

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.078722945722115e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
